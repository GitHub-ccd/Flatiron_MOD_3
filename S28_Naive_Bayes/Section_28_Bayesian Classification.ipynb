# %% [markdown]
# # Section 28 - Bayesian Classification - lessons and labs
#
#
# [bayesian-classification-intro-v2-1](./dsc-bayesian-classification-intro-v2-1-onl01-dtsc-ft-030220/index.ipynb)<br>
#
#
# [classifiers-with-bayes](./dsc-classifiers-with-bayes-onl01-dtsc-ft-030220/index.ipynb)<br>
# - Explain the assumption that leads to Naive Bayes being "naive"
# - Explain how to use the probabilities generated by Naive Bayes to make a classification
#
# [gaussian-naive-bayes](./dsc-gaussian-naive-bayes-onl01-dtsc-ft-030220/index.ipynb)<br>
# - Theoretical background
# - example with iris.data
# - conditional probability point estimates
# - Multinomial Bayes
# - class probabilities for observations
# - Calculating accuracy
#
# [gaussian-naive-bayes-lab](./dsc-gaussian-naive-bayes-lab-onl01-dtsc-ft-030220/index.ipynb)<br>
#
#
# [document-classification-with-naive-bayes](./dsc-document-classification-with-naive-bayes-onl01-dtsc-ft-030220/index.ipynb)<br>
#
#
# [document-classification-with-naive-bayes-lab](./dsc-document-classification-with-naive-bayes-lab-onl01-dtsc-ft-030220/index.ipynb)<br>
#
#
# [bayesian-classification-recap-v2-1](./dsc-bayesian-classification-recap-v2-1-onl01-dtsc-ft-030220/index.ipynb)<br>
